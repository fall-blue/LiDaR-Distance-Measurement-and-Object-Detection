# %% [markdown]
# <a href="https://colab.research.google.com/github/fall-blue/IRIS-Project/blob/main/IRIS_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **IRIS OBJECT DETECTION CODE**
# In this colab file you can test our object detection model with your own image or video.
#
# This model is trained to detect the following objects:
# *   Chairs
# *   Tables
# *   Sofas
# *   Fireplaces
#
# **DISCLAIMER: this is just a prototype and the model is still in development we are actively working on expanding our dataset to incorporate more object classes, enhancing the model's versatility, performance and accuracy.**
#
#
#
# ---
#
#
#
# **IMPORTANT**
#
# Make sure to change the runtime type and set the hardware accelerator to T4 GPU
#
# **Steps:**
#
#
#
# 1. Click on runtime
# ![Screenshot 2023-10-25 at 12.11.05 AM-mh.png](data:image/png;base64,...)
# 2. Click on change runtime type
# ![Screenshot 2023-10-25 at 12.17.24 AM-mh.png](data:image/png;base64,...)
# 3. Click on T4 GPU
# ![Screenshot 2023-10-25 at 12.19.10 AM-mh.png](data:image/png;base64,...)
# 4. Click on save
# ![Screenshot 2023-10-25 at 12.22.00 AM-mh.png](data:image/png;base64,...)

# %% [markdown]
# ## **DOWNLOADING THE REQUIRED DEPENDENCIES**

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

#This code installs a specific software component, clears any displayed content,and then verifies that the newly installed component is functioning properly.

# %%
# !git clone https://github.com/fall-blue/Living-Room-Object-Detection.git

#This code clones a GitHub repository named "Living-Room-Object-Detection" into your current directory using Git.

# %% [markdown]
# ## **MODEL TESTING**

# %%
# !yolo task=detect mode=predict model=/content/Living-Room-Object-Detection/Yolov8_ObjectDetection.pt conf=0.25 source='' save=True

#This code runs a YOLO object detection task in prediction mode using a specified model file, with a confidence threshold of 0.25, on an unspecified data source, and saves the results.

# %% [markdown]
# **Important:**
#
# First you need to upload the image or the video you want to test with our machine learning model.
#
# Make sure the file path of the Object detection model that you cloned earlier from our github repository is pasted in `model=''`.
#
# **Steps**: [Click here for instructions](https://1drv.ms/w/s!AicPYeTK2g37hVQRH9bwn-57OHsW?e=qANScC)
#
# **(NOTE: Please ensure that you read the instructions above to correctly execute the code; failure to do so may result in encountering errors.)**
#
# `source='(here you need to provide the path of the image or video you want to test)'`
#
# for eg.
#
# `source='/content/SampleVideo.mp4'`
#
# `source='/content/SampleImage.jpg'`
#
# `source='/content/SampleImage.png'`
